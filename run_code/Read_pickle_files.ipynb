# %%
import pickle
# import copy
# import os
# import sys
import numpy as np
from datetime import datetime as dt,timedelta

# %%
m=12
varname='SOIL'
# varname='colIrr'
# eof = pickle.load(open(f'/Projects/jalbers_process/CPC_LIM/yuan_ming/Data/9b_sliding_climo_no_double_running_mean/data_clim/tmp/EOF_JRA_58-16_sliding_climo_{varname}_{m}.p', "rb" ) )
data = pickle.load(open(f'/Projects/jalbers_process/CPC_LIM/yuan_ming/Data/9b_sliding_climo_no_double_running_mean/data_clim/tmp/fullyr_JRA_58-16_sliding_climo_T2m.p', "rb" ) )

# %%
data['data'].plot_map()
# Out:
# /home/ycheng/LIM/CPC/run_code/lib/dataset.py:418: RuntimeWarning: Mean of empty slice
# <GeoAxesSubplot:>

# %%
eof.plot()

# %%
DataSam = pickle.load(open('/Projects/LIM/Realtime/Realtime/webData/data_clim/tmp/fullyr_JRA_79-17_T2m.p',"rb"))

for i in DataSam.items():
    print(i)
print((DataSam['data'].time))
# Out:
# ('info', ('/Projects/LIM/Realtime/CPCWeeks34/RT_LIM_CODE/rawdata/T2m', 'anomaly', {'latbounds': (20, 74), 'lonbounds': (190, 305), 'datebounds': ('1/1', '12/31'), 'season0': True, 'climoyears': (1979, 2017), 'time_window': 7, 'coarsegrain': 2.5, 'landmask': True}))
# ('data', <lib.dataset.varDataset object at 0x7f59c896be50>)
# [real_datetime(1979, 1, 15, 0, 0) real_datetime(1979, 1, 16, 0, 0)
#  real_datetime(1979, 1, 17, 0, 0) ... real_datetime(2017, 12, 29, 0, 0)
#  real_datetime(2017, 12, 30, 0, 0) real_datetime(2017, 12, 31, 0, 0)]

# %%
m=12
varname='SOIL'
# varname='colIrr'
eof2 = pickle.load(open(f'/Projects/jalbers_process/CPC_LIM/yuan_ming/Data/9_sliding_climo/data_clim/tmp/EOF_JRA_58-16_sliding_climo_{varname}_{m}.p', "rb" ) )
eof2.plot()

# %%
# eof1 = pickle.load(open(f'/Projects/jalbers_process/CPC_LIM/yuan_ming/Data/10b2_using_my_rawdata/data_clim/tmp/EOF_JRA_79-17_{varname}_{m}.p', "rb" ) )
# eof1.plot()
# eofobjs = eof1
# eofobjs.varobjs[0].time
# eofobjs.eof_dict['pc']

# %%
varname = 'colIrr'# 2 degree
varname = 'SLP'# 4 degree
varname = 'H500'# 4 degree
varname = 'H100'# 4 degree
varname = 'T2m'# 2.5 degree
data = pickle.load( open(f'/Projects/jalbers_process/CPC_LIM/yuan_ming/Data/data_climo_Sam/fullyr_JRA_79-17_{varname}.p', "rb"))
# print(data['data'].lon)
data['data'].plot_map()
# Out:
# /home/ycheng/LIM/CPC/run_code/lib/dataset.py:418: RuntimeWarning: Mean of empty slice
# <GeoAxesSubplot:>

# %%
date = dt(1989,7,31)
data['data'].plot_map(time=date)
# Out:
# /home/ycheng/LIM/CPC/run_code/lib/dataset.py:418: RuntimeWarning: Mean of empty slice
# <GeoAxesSubplot:>

# %%
data2 = pickle.load( open(f'/Projects/jalbers_process/CPC_LIM/yuan_ming/Data/10b2_using_my_rawdata/data_clim/tmp/fullyr_JRA_79-17_T2m.p', "rb"))
data2['data'].plot_map(time=date)
# Out:
# /home/ycheng/LIM/CPC/run_code/lib/dataset.py:418: RuntimeWarning: Mean of empty slice
# <GeoAxesSubplot:>

# %%
data2['data'].coarsegrain
# Out:
# 2

# %%
timeseries = [1,2,3,4,5,6,7,8]
timeseries[0:2]
# Out:
# [1, 2]

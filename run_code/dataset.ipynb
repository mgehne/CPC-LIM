# %%
import xarray as xr
import numpy as np
import netCDF4 as nc

# %%
ds = xr.open_dataset('/data/ycheng/JRA/Data/make_rawdata_offline_climatology/2p0.1971-2000//sf/sf_1971_1p25.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:        (isobaricInhPa: 37, latitude: 145, longitude: 288, time: 365)
# Coordinates:
#     number         int64 ...
#     step           timedelta64[ns] ...
#   * isobaricInhPa  (isobaricInhPa) float64 1e+03 975.0 950.0 ... 3.0 2.0 1.0
#   * latitude       (latitude) float64 90.0 88.75 87.5 ... -87.5 -88.75 -90.0
#   * longitude      (longitude) float64 0.0 1.25 2.5 3.75 ... 356.2 357.5 358.8
#   * time           (time) datetime64[ns] 1971-01-01 1971-01-02 ... 1971-12-31
# Data variables:
#     strf           (time, isobaricInhPa, latitude, longitude) float32 ...

# %%
ds0 = nc.Dataset('/data/ycheng/JRA/Data/make_rawdata_offline_climatology/2p0.1971-2000//sf/sf_1971_1p25.nc')

            

# lat_name = ([s for s in ds0.variables.keys() if 'lat' in s]+[None])[0]
# lon_name = ([s for s in ds0.variables.keys() if 'lon' in s]+[None])[0]
# lev_name = ([s for s in ds0.variables.keys() if 'lev' in s or 'lv_' in s]+[None])[0]
# time_name = ([s for s in ds0.variables.keys() if 'time' in s]+[None])[0]
# var_name = self.varname

# %%
from datetime import datetime as dt,timedelta
import xarray as xr

# %%
diri = '/Projects/jalbers_process/CPC_LIM/yuan_ming/JRA-3Q/JRA-55_test/'
filename = f'{diri}fcst_phy2m125.2023122100'
ds1 = xr.open_dataset(filename, engine='cfgrib', \
                     backend_kwargs={'filter_by_keys':{'typeOfLevel': 'surface'}})

dsw_sfc = ds1['dswrf'] # W m**-2
dlw_sfc = ds1['dlwrf'] # W m**-2
usw_sfc = ds1['uswrf'] # W m**-2
ulw_sfc = ds1['ulwrf'] # W m**-2
shf = ds1['shf'] # W m**-2
pcp = ds1['tpratsfc'] # mm per day

densw = 1e3 # kg m**-3
day_per_sec = 1/(60*60*24)
m_per_mm = 1e-3
pcp = pcp * day_per_sec * m_per_mm * densw # kg m**-2 s**-1
L = 2.260e6 # J kg**-1

ds2 = xr.open_dataset(filename, engine='cfgrib', \
                     backend_kwargs={'filter_by_keys':{'typeOfLevel': 'nominalTop'}})

dsw_nt = ds2['dswrf'] # W m**-2
usw_nt = ds2['uswrf'] # W m**-2
ulw_nt = ds2['ulwrf'] # W m**-2

# %%
diri = '/Projects/jalbers_process/CPC_LIM/yuan_ming/JRA-3Q/JRA-55_test/'
filename = f'{diri}anl_land125.2023122100'
ds = xr.open_dataset(filename, engine='cfgrib')
# ,                      backend_kwargs={'filter_by_keys':{'typeOfLevel': 'surface'}})

# %%
ds['ussl']
# Out:
# <xarray.DataArray 'ussl' (threeLayers: 3, latitude: 145, longitude: 288)>
# [125280 values with dtype=float32]
# Coordinates:
#     number       int64 ...
#     time         datetime64[ns] ...
#     step         timedelta64[ns] ...
#     surface      float64 ...
#   * latitude     (latitude) float64 90.0 88.75 87.5 86.25 ... -87.5 -88.75 -90.0
#   * longitude    (longitude) float64 -1.25 0.0 1.25 2.5 ... 355.0 356.2 357.5
#     valid_time   datetime64[ns] ...
#     deepSoil     float64 ...
#   * threeLayers  (threeLayers) float64 1.0 2.0 3.0
# Attributes: (12/30)
#     GRIB_paramId:                             300182
#     GRIB_dataType:                            0
#     GRIB_numberOfPoints:                      41760
#     GRIB_typeOfLevel:                         threeLayers
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
# ...

# %%
diri = '/Projects/jalbers_process/CPC_LIM/yuan_ming/JRA-3Q/JRA-55_test/'
filename = f'{diri}fcst_surf125.2023122200'
ds = xr.open_dataset(filename, engine='cfgrib',backend_kwargs={'filter_by_keys':{'cfVarName':'btmp'}})

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (latitude: 145, longitude: 288)
# Coordinates:
#     number      int64 ...
#     time        datetime64[ns] ...
#     step        timedelta64[ns] ...
#     surface     float64 ...
#   * latitude    (latitude) float64 90.0 88.75 87.5 86.25 ... -87.5 -88.75 -90.0
#   * longitude   (longitude) float64 -1.25 0.0 1.25 2.5 ... 355.0 356.2 357.5
#     valid_time  datetime64[ns] ...
# Data variables:
#     btmp        (latitude, longitude) float32 ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             rjtd
#     GRIB_centreDescription:  Japanese Meteorological Agency - Tokyo
#     GRIB_subCentre:          241
#     Conventions:             CF-1.7
#     institution:             Japanese Meteorological Agency - Tokyo
#     history:                 2024-01-13T12:46 GRIB to CDM+CF via cfgrib-0.9.1...

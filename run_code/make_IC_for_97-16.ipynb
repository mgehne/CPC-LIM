# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from datetime import datetime as dt,timedelta

# %%
import os
from os import system

# %%
# for year in range(2017,2022,1):
RETROdata_path = '/scratch/ycheng/JRA/Data/97-16_climo/data_retrospective'

# RT_VARS = ['T2m','SOIL','SLP','colIrr','H500','SST', 'SOIL','SF100','SF750']# change RT_VARS in namelist
RT_VARS = ['T2m']
os.system(f'rm -r {RETROdata_path}')

for var in RT_VARS:
    print(var)
    os.system(f'mkdir -p {RETROdata_path}')
    ds_97_16 = xr.open_dataset(f'/scratch/ycheng/JRA/Data/97-16_climo/{var}/{var}.2000.nc')
    # ds_97_16 = [xr.open_dataset(f'/scratch/ycheng/JRA/Data/97-16_climo/{var}/{var}.{year}.nc') for year in range(2017,2022,1)]
    ds_58_14 =  xr.open_dataset(f'/scratch/ycheng/JRA/Data/58-14_climo/{var}/extra_years/{var}.2020.nc')
    # ds_58_14 =  xr.open_dataset(f'/scratch/ycheng/JRA/Data/58-14_climo/{var}/extra_years/{var}.2020.nc')
    varlist = ds_97_16['climo']+ds_58_14['climo'] 
    # varlist = [dstmp+ds_58_14['climo'] for dstmp in ds_97_16 ]
    # combined_dataset = xr.concat(varlist, dim='time')
    # combined_dataset.to_netcdf(f'{RETROdata_path}/{var}.All.nc')
# Out:
# T2m

# %%
varlist = varlist.assign_coords({'doy':np.arange(3,365+3)})
varlist.rename({'doy':'time'})
# Out:
# <xarray.DataArray 'climo' (time: 365, lat: 91, lon: 180)>
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
# ...
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
# ...

# %%
lat = 40
lon = 250
print(ds_97_16[0]['anomaly'].sel(time='2017-12-05',lat=lat, lon=lon))
# Out:
#   Cell In[25], line 3
#     print(ds_97_16[0]['anomaly'].sel(time='2017-12-05',lat=lat, lon=lon))(:)
#                                                                           ^
# SyntaxError: invalid syntax

# %%
anomaly = varlist[0]['anomaly']
anom.sel(time='2017-12-05',lat=lat, lon=lon)
# Out:
# <xarray.DataArray 'anomaly' (doy: 365)>
# array([270.68808, 270.66846, 270.6547 , 270.6468 , 270.64468, 270.64835,
#        270.65768, 270.6727 , 270.6933 , 270.71942, 270.75098, 270.78793,
#        270.83017, 270.8776 , 270.93018, 270.98773, 271.05023, 271.11755,
#        271.18958, 271.2662 , 271.3473 , 271.43274, 271.52243, 271.61624,
#        271.71405, 271.8157 , 271.92108, 272.03003, 272.14246, 272.2582 ,
#        272.37714, 272.49908, 272.62396, 272.7516 , 272.88184, 273.0146 ,
#        273.14966, 273.28693, 273.42627, 273.56757, 273.71063, 273.85538,
#        274.00165, 274.14932, 274.29828, 274.4484 , 274.59955, 274.75162,
#        274.90448, 275.058  , 275.21216, 275.3668 , 275.5218 , 275.6771 ,
#        275.83258, 275.9882 , 276.14383, 276.29944, 276.45493, 276.61023,
#        276.76532, 276.92007, 277.0745 , 277.22855, 277.38214, 277.53528,
#        277.6879 , 277.84   , 277.99158, 278.1426 , 278.29306, 278.44293,
# ...

# %%
ds = xr.open_dataset('/scratch/ycheng/JRA/Data/97-16_climo/data_retrospective/SOILAll.nc')

# %%
ds['time']
# Out:
# <xarray.DataArray 'time' (time: 1826)>
# array(['2017-01-01T00:00:00.000000000', '2017-01-02T00:00:00.000000000',
#        '2017-01-03T00:00:00.000000000', ..., '2021-12-29T00:00:00.000000000',
#        '2021-12-30T00:00:00.000000000', '2021-12-31T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2017-01-01 2017-01-02 ... 2021-12-31
# Attributes:
#     long_name:      Time
#     delta_t:        0000-00-01 00:00:00
#     standard_name:  time
#     axis:           T

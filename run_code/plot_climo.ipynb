# %%
import xarray as xr
import matplotlib.pyplot as plt
from cartopy import crs as ccrs
import numpy as np
from lib import driver
import pandas as pd
import os
import pickle

# %%
ds = xr.open_dataset('/Projects/jalbers_process/CPC_LIM/yuan_ming/Data/offline_climatology/2p0.1981-2010/data_clim/2p0.1981-2010_T2m.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 365, pts: 696)
# Coordinates:
#   * time     (time) datetime64[ns] 1981-01-01 1981-01-02 ... 1981-12-31
# Dimensions without coordinates: pts
# Data variables:
#     T2m      (time, pts) float32 ...
#     lat      (pts) float64 ...
#     lon      (pts) float64 ...

# %%
Samdata = pickle.load( open(f'/Projects/jalbers_process/CPC_LIM/yuan_ming/Data/data_climo_Sam/fullyr_JRA_79-17_CPCtemp.p', "rb"))
dir(Samdata['data'])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_date_range_test',
#  'attrs',
#  'climo',
#  'climo_mean',
#  'climo_stdev',
#  'climoyears',
#  'coarsegrain',
#  'datapath',
#  'datebounds',
#  'domain',
#  'flatten',
#  'get_ds',
#  'get_latest',
#  'landmask',
#  'lat',
#  'latbounds',
#  'latgrid',
#  'level',
#  'lon',
#  'lonbounds',
#  'longrid',
#  'mapgrid',
#  'plot_map',
#  'regrid',
#  'running_mean',
#  'save_to_netcdf',
#  'smoother',
#  'subset',
#  'time',
#  'time_window',
#  'varlabel',
#  'varname']

# %%
LIMdriver = driver.Driver(f'namelist_cpc_offline_climatology.py')
# read in data
# LIMdriver.get_variables(read=True)
# obj = LIMdriver.use_vars['T2m']['data']
T2m = dsSam.T2m.values
T2mMap = [Samdata['data'].regrid(daily) for daily in T2m]
# Out:
# cyms file here
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 6
#       2 # read in data
#       3 # LIMdriver.get_variables(read=True)
#       4 # obj = LIMdriver.use_vars['T2m']['data']
#       5 T2m = dsSam.T2m.values
# ----> 6 T2mMap = [Samdata['data'].regrid(daily) for daily in T2m]
#
# Cell In[34], line 6, in <listcomp>(.0)
#       2 # read in data
#       3 # LIMdriver.get_variables(read=True)
#       4 # obj = LIMdriver.use_vars['T2m']['data']
#       5 T2m = dsSam.T2m.values
# ----> 6 T2mMap = [Samdata['data'].regrid(daily) for daily in T2m]
#
# File ~/LIM/CPC/run_code/lib/dataset.py:354, in varDataset.regrid(self, a)
#     350 def regrid(self,a):
#     351     # Take 1-d vector of same length as domain
#     352     # and transform to original grid
#     353     b = self.mapgrid.copy()
# --> 354     b[self.domain] = a
#     355     return b
#
# ...

# %%
dsSam = xr.open_dataset('./data_clim/CPC.2p0.1981-2010.nc')
# fig,ax = plt.subplots()
# contour_levels = np.arange(-15,15,3)  # Replace with your desired contour levels
# lat_bounds = [15, 75]  # Replace with your desired latitude boundaries
# lon_bounds = [190, 305]  
# dsSam.T2m.isel(time=0).plot.contourf(ax=ax,levels=contour_levels,projection=ccrs.PlateCarree())
# ax.set_xlim([lon_bounds[0], lon_bounds[1]])
# ax.set_ylim([lat_bounds[0], lat_bounds[1]])
dsSam.lat
# Out:
# <xarray.DataArray 'lat' (pts: 1566)>
# [1566 values with dtype=float32]
# Dimensions without coordinates: pts

# %%
dsSam
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 365, pts: 1566)
# Coordinates:
#   * time     (time) datetime64[ns] 1981-01-01 1981-01-02 ... 1981-12-31
# Dimensions without coordinates: pts
# Data variables:
#     T2m      (time, pts) float32 ...
#     lat      (pts) float32 ...
#     lon      (pts) float32 ...

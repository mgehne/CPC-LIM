# %%
import pickle
import sys
sys.path.append('../') # This allows import of lib that is one level up
import lib

# %%
diri = '/Projects/jalbers_process/CPC_LIM/yuan_ming/Data/'
# expt_name1 = '9b_sliding_climo_no_double_running_mean'
expt_name1 = 'fixed_58-16_climo_reforecast'
m=12
varname='T2m'
eof1 = pickle.load(open(f'{diri}{expt_name1}/data_clim/tmp/EOF_JRA_58-16_sliding_climo_{varname}_{m}.p', "rb" ))
plots = eof1.plot()

# %%
diri = '/Projects/jalbers_process/CPC_LIM/yuan_ming/Data/'
# expt_name2 = 'v2p0_EOF_period_centering_reforecast'
expt_name2 = 'fixed_58-16_climo_test_reforecast'

m=12
varname='T2m'
eof2 = pickle.load(open(f'{diri}{expt_name2}/data_clim/tmp/EOF_JRA_58-16_sliding_climo_{varname}_{m}.p', "rb" ))
eof2.plot()
